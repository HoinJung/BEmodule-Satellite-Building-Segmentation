# %%
import matplotlib.pyplot as plt
import numpy as np
import skimage.io
import sklearn.metrics as sm
import sys
import os
import datetime
from skimage import img_as_uint
from skimage.filters import threshold_otsu, threshold_niblack
import cv2
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib
import pandas as pd
import shutil


plt.rcParams.update({'font.size': 6})
mpl.rcParams['figure.dpi'] = 300
sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname("__file__"))))
os.environ['CUDA_VISIBLE_DEVICES']='2'
# aois = 3
# training_date = '1272229'
aois = 3
training_date = '221343'
dirmode= False
# dirmode= True
if aois ==2 :
    aoi = 'AOI_2_Vegas'
elif aois == 3: 
    aoi = 'AOI_3_Paris'
elif aois == 4: 
    aoi = 'AOI_4_Shanghai'
elif aois==5 :
    aoi = 'AOI_5_Khartoum'


im_dir = '../data/Test/' + aoi + '_Test/'
pred_top_dir = '../result/'

# %%
def revision_metric(sq_segment_mask_ori, sq_segment_mask_pred):
    #sq_segment_mask_ori_ = list(sq_segment_mask_ori.ravel().astype(int))
    #sq_segment_mask_pred_ = list(sq_segment_mask_pred.ravel().astype(int))
    sq_segment_mask_ori_ = sq_segment_mask_ori.ravel().astype(int)
    sq_segment_mask_pred_ = sq_segment_mask_pred.ravel().astype(int)
    
    accuracy_ = sm.accuracy_score(sq_segment_mask_ori_, sq_segment_mask_pred_)
    bal_accu = sm.jaccard_score(sq_segment_mask_ori_, sq_segment_mask_pred_)
    f1_score = sm.f1_score(sq_segment_mask_ori_, sq_segment_mask_pred_)
    recall = sm.recall_score(sq_segment_mask_ori_, sq_segment_mask_pred_)
    precision = sm.precision_score(sq_segment_mask_ori_, sq_segment_mask_pred_)
    
    return accuracy_,  f1_score, recall, precision, bal_accu
#     tn, fp, fn, tp =  sm.confusion_matrix(sq_segment_mask_ori_, sq_segment_mask_pred_).ravel()
#     FAR = float(fp)/(tn+fp)*100
    
#     return accuracy_, f1_score, recall, precision, FAR

# %%
#get mask
if dirmode:
    infer_dir = os.path.join(pred_top_dir+ 'infer'+ '/'+ aoi + '_' + training_date+'/check_mask_presigmoid/')
else :
    infer_dir = os.path.join(pred_top_dir+ 'infer'+ '/'+ aoi + '_' + training_date)
out_dir_mask = os.path.join(pred_top_dir+ 'infer_masks'+ '/' +aoi  +'_' + training_date)
print(infer_dir)
print(out_dir_mask)
if os.path.isdir(out_dir_mask) :
    shutil.rmtree(out_dir_mask)
    os.makedirs(out_dir_mask, exist_ok=True)
else : 
    os.makedirs(out_dir_mask, exist_ok=True)
im_list = sorted([z for z in os.listdir(infer_dir) if z.endswith('.tif')])


for i,j in enumerate(im_list):
    name_root = j.split('.')[0]
#     print(name_root)
    image_path = os.path.join(infer_dir,name_root+'.tif')
    if dirmode:
        mask_path = os.path.join(out_dir_mask,name_root+'.tif').replace('sum_infer_AOI','pred_mask_AOI')
    else : 
        mask_path = os.path.join(out_dir_mask,name_root+'.tif').replace('mask_AOI','pred_mask_AOI')
    mask_image = skimage.io.imread(image_path)
    
    binary = mask_image > 0

    skimage.io.imsave(mask_path, binary)
# Out:
# ../result/infer/AOI_3_Paris_221343
# ../result/infer_masks/AOI_3_Paris_221343
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img10.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img10.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img100.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img101.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img102.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img103.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img107.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img108.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img108.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img109.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img110.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img111.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img113.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img115.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img115.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img118.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img119.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img119.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img12.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img12.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img121.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img122.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img123.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img124.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img125.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img127.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img128.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img132.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img132.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img133.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img134.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img135.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img136.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img137.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img139.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img14.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img14.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img140.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img142.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img143.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img146.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img147.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img147.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img151.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img154.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img155.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img156.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img157.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img158.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img159.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img159.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img160.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img160.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img162.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img162.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img163.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img163.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img164.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img165.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img166.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img168.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img17.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img17.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img173.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img174.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img178.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img178.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img181.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img182.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img183.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img185.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img186.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img188.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img189.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img19.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img19.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img191.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img193.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img193.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img194.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img194.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img196.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img197.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img20.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img20.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img200.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img202.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img203.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img204.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img204.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img205.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img205.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img206.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img206.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img208.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img208.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img209.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img209.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img21.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img21.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img211.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img212.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img214.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img215.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img216.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img217.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img219.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img220.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img225.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img228.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img229.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img23.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img23.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img230.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img232.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img233.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img233.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img234.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img235.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img24.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img24.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img240.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img241.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img242.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img243.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img244.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img244.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img245.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img245.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img250.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img252.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img252.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img254.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img258.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img26.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img260.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img261.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img261.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img263.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img263.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img269.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img269.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img27.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img270.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img270.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img271.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img271.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img272.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img272.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img276.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img277.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img278.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img28.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img280.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img282.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img283.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img284.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img287.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img287.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img289.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img289.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img292.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img292.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img293.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img293.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img294.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img294.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img297.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img297.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img298.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img298.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img299.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# ...
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img4.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img40.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img40.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img41.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img41.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img43.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img43.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img44.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img44.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img46.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img46.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img47.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img47.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img49.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img49.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img5.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img5.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img50.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img50.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img52.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img52.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img56.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img56.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img59.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img59.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img6.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img6.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img62.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img62.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img63.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img63.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img69.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img69.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img70.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img70.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img73.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img73.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img74.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img74.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img75.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img78.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img78.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img8.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img8.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img83.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img83.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img85.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img85.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img86.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img88.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img88.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img89.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img90.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img92.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img94.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img94.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img95.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img95.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img96.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img98.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img98.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/AOI_3_Paris_221343/pred_mask_AOI_3_Paris_img99.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.

# %%
#compare target, ground truth, prediction
import skimage
import skimage.segmentation
import copy
im_list = sorted([z for z in os.listdir(os.path.join(im_dir,'RGB')) if z.endswith('.tif')])
# sample_name= im_list[25]
sample_name= im_list[27]
# sample_name= im_list[30]
# print(sample_name)
gt_path = os.path.join(im_dir, 'masks', sample_name).replace('RGB-PanSharpen','buildings')
image_pt = os.path.join(im_dir, 'RGB', sample_name)
if dirmode:
    infer_path = os.path.join(infer_dir+ '/'+ sample_name).replace('RGB-PanSharpen','sum_infer')
else : 
    infer_path = os.path.join(infer_dir+ '/'+ sample_name).replace('RGB-PanSharpen','mask')
prediction_path = os.path.join(out_dir_mask+ '/'+ sample_name).replace('RGB-PanSharpen','pred_mask')


img = cv2.imread(image_pt,cv2.IMREAD_UNCHANGED )
img = img.astype(np.uint16)
# cv2.imwrite('processed.tif',img )

gt_image = skimage.io.imread(gt_path)
infer_image = skimage.io.imread(infer_path)
mask_image = skimage.io.imread(prediction_path)
binary = mask_image > 0
# temp_infer = copy.copy(infer_image)
# temp_infer[ temp_infer >=0 ] = 255
# temp_infer[ temp_infer < 0 ] = 0

boundary = skimage.segmentation.find_boundaries(binary, mode='inner', background=0).astype(np.float32)
boundary=boundary*255
print("mask_image.shape:", mask_image.shape)
print("min, max", np.min(mask_image), np.max(mask_image))
print("gt.shape:", gt_image.shape)
print("min, max", np.min(gt_image), np.max(gt_image))
print("infer_image.shape:", infer_image.shape)
print("min, max", np.min(infer_image), np.max(infer_image))
print("boundary:", boundary.shape)
print("min, max", np.min(boundary), np.max(boundary))
#1 boundary ground truth를 255를 곱하자
#2 boundary output에도 255 곱하고.. 그래야 balance가 맞을듯.

print(np.unique(boundary))
fig = plt.figure(figsize=(8,8))
rows=2
cols=2
ax0 = fig.add_subplot(rows, cols, 1)
ax1 = fig.add_subplot(rows, cols, 2)
ax2 = fig.add_subplot(rows, cols, 3)
ax3 = fig.add_subplot(rows, cols, 4)
ax0.imshow(img)
# ax0.imshow(infer_image,cmap='gray')
ax0.axis('off')
ax0.set_title('Image')
ax1.imshow(gt_image,cmap='gray')
ax1.axis('off')
ax1.set_title('Ground Truth')
ax2.imshow(infer_image,cmap='gray')
ax2.axis('off')
ax2.set_title('Infer Image')
ax3.imshow(mask_image,cmap='gray')
ax3.axis('off')
ax3.set_title('Prediction Mask')
plt.suptitle(sample_name.split('.')[0])
plt.tight_layout()
plt.show()
# fig.savefig(eval_path+'_result',dpi=100)
# Out:
# mask_image.shape: (650, 650)
# min, max 0 255
# gt.shape: (650, 650)
# min, max 0 255
# infer_image.shape: (650, 650)
# min, max -29.357204 5.215769
# boundary: (650, 650)
# min, max 0.0 255.0
# [  0. 255.]

# %%
# from sklearn.metrics import roc_curve
# from sklearn.metrics import roc_auc_score

# testy = gt_image/255.
# ns_probs = mask_image

# s_auc = roc_auc_score(testy, ns_probs)
 
# # summarize scores
# #print('No Skill: ROC AUC=%.3f' % (ns_auc))
 
# # calculate roc curves
# ns_fpr, ns_tpr, _ = roc_curve(testy, ns_probs)
 
# # plot the roc curve for the model
# plt.plot(ns_fpr, ns_tpr, linestyle='--', label='No Skill')
 
# # show the plot
# plt.show()

# %%
# im_list = sorted([z for z in os.listdir(os.path.join(im_dir,'RGB')) if z.endswith('.tif')])
# # sample_name= im_list[25]
# sample_name= im_list[27]
# # sample_name= im_list[1]
# # print(sample_name)
# gt_path = os.path.join(im_dir, 'masks', sample_name).replace('RGB-PanSharpen','buildings')
# image_pt = os.path.join(im_dir, 'RGB', sample_name)
# if dirmode:
#     infer_path = os.path.join(infer_dir+ '/'+ sample_name).replace('RGB-PanSharpen','sum_infer')
# else : 
#     infer_path = os.path.join(infer_dir+ '/'+ 'check_mask_presigmoid/'+sample_name).replace('RGB-PanSharpen','sum_infer')
# #     infer_path = os.path.join(infer_dir+ '/'+ sample_name).replace('RGB-PanSharpen','mask')
# # prediction_path = os.path.join(out_dir_mask+ '/'+ sample_name).replace('RGB-PanSharpen','pred_mask')
# boundary_path = os.path.join(infer_dir+ '/'+ 'boundary/'+sample_name).replace('RGB-PanSharpen','Boundary')
# sum_path = os.path.join(infer_dir+ '/'+ 'binary/'+sample_name).replace('RGB-PanSharpen','binary')
# gt_image2 = skimage.io.imread(gt_path)
# infer_image2 = skimage.io.imread(infer_path)
# boundary_image = skimage.io.imread(boundary_path)
# sum_image = skimage.io.imread(sum_path)

# a=260
# b=360
# c=200

# N=100
# X = np.zeros(N)
# X[:] = np.linspace(1,N,N)
# Y_max = 1.1
# y_min=0.0
# print(mask_image.shape)
# infer_arr = infer_image2[a:b,c]
# gt_arr = gt_image2[a:b,c]/255
# boundary_arr = boundary_image[a:b,c]
# boundary_arr2 = 5*boundary_image[a:b,c]
# test_arr =np.clip(boundary_arr2 + infer_arr,0,1)
# sum_arr = sum_image[a:b,c]
# plt.rcParams['figure.figsize'] = (10,6)
# plt.rcParams.update({'font.size': 7})

# # title of plot
# plt.title('Softmax' )

# # plotting result graph
# plt.xlabel('x')  
# plt.ylabel('P(x)') 
# plt.xlim(0,N)
# plt.ylim(y_min,Y_max)

# plt.tick_params(axis='x', direction='inout', length=6, pad=6, labelsize=6)
# plt.tick_params(axis='y', direction='inout', length=6, pad=15, labelsize=6,)

# plt.plot(X[:], infer_arr,'-r',label='predicted mask')
# plt.plot(X[:], gt_arr,'-g',label='ground truth')
# # plt.plot(X[:], boundary_arr,'-b',label='boundary')
# # plt.plot(X[:], sum_arr,'-k',label='sum(mask+edge)')
# plt.plot(X[:], boundary_arr2,'-b',label='predicted boundary')
# plt.plot(X[:], test_arr,'-.k',label='enhanced mask')
# plt.grid(True)
# plt.legend()
# fig1=plt.gcf()
# plt.show()
# plt.draw()
# # if not os.path.exists('result_graph'):
# #     os.makedirs('result_graph')   
# # fig1.savefig(eval_path+'_loss_fig.png',dpi=100)

# %%
eval_result = revision_metric(gt_image/255., mask_image/255.)
print(eval_result)
# Out:
# (0.9605846153846154, 0.8390034513761999, 0.8461943485637395, 0.8319337397906361, 0.7226580064951287)

# %%
def average(list):
    return (sum(list) / len(list))

eval_path = os.path.join(pred_top_dir+'eval_result'+'/'+aoi+'_'+training_date)
os.makedirs(eval_path, exist_ok=True)
gt_list= sorted([z for z in os.listdir(os.path.join(im_dir,'masks')) if z.endswith('.tif')])
# mask_list=sorted([z for z in os.listdir(os.path.join(pred_top_dir,'infer_masks')) if z.endswith('.tif')])
print("list_len : ", len(gt_list))

eval_list = []
mask_list=[]
acc_list=[]
f1_list = []
rec_list = []
prec_list = []
bal_acc_list=[]
for i,j in enumerate(gt_list) : 
    mask_name = j.split('.')[0]
#     print(mask_name)
    gt_array = skimage.io.imread(os.path.join(im_dir, 'masks',mask_name+'.tif'))
    eval_mask = os.path.join(out_dir_mask+ '/'+mask_name+'.tif').replace('buildings','pred_mask')
    
#     eval_mask = os.path.join(pred_top_dir, 'infer_masks',mask_name+'.tif').replace('buildings','pred_mask')
    mask_array = skimage.io.imread(eval_mask)
    eval_result = revision_metric(gt_array/255., mask_array/255.)
    
#     print("accuracy : %.3f " % eval_result[0], end=',')
#     print("f1_score : %.3f " % eval_result[1], end=',')
#     print("recall : %.3f " % eval_result[2], end=',')
#     print("precision : %.3f " % eval_result[3])
    
    acc_list.append(eval_result[0])
    f1_list.append(eval_result[1])
    rec_list.append(eval_result[2])
    prec_list.append(eval_result[3])
    bal_acc_list.append(eval_result[4])



acc_list_nonzero = [i for i in acc_list if i > 0 ] 
f1_list_nonzero = [i for i in f1_list if i > 0 ]    
rec_list_nonzero = [i for i in rec_list if i > 0 ]    
prec_list_nonzero = [i for i in prec_list if i > 0 ]  
bal_acc_list_nonzero = [i for i in bal_acc_list if i > 0 ]  


a=round(average(acc_list),5)
b=round(average(f1_list),5)
c=round(average(rec_list),5)
d=round(average(prec_list),5)
e=round(average(acc_list_nonzero),5)
f=round(average(f1_list_nonzero),5)
g=round(average(rec_list_nonzero),5)
h=round(average(prec_list_nonzero),5)

x=round(average(bal_acc_list),5)
y= round(average(bal_acc_list_nonzero),5)


print("accuray = %.5f  / %.5f" % (a,e))
print("precision = %.5f / %.5f" % (d, h))
print("recall = %.5f / %.5f" % (c, g))
print("f1_score = %.5f / %.5f" % (b, f))



eval_df = pd.DataFrame(columns=['file_name','accuracy',  'precision', 'recall', 'f1_score','bal_accuracy'])
eval_df.loc[0] = ("Average",a,d,c,b,x)
eval_df.loc[1] = ("Average(nonzero)",e,h,g,f,y)
eval_result = pd.DataFrame([x for x in zip(gt_list,acc_list, prec_list, rec_list, f1_list,bal_acc_list )], columns=['file_name','accuracy',  'precision', 'recall', 'f1_score', 'bal_accuracy'])    
evaldf = eval_df.append(eval_result)

evaldf.to_csv(eval_path+"_eval_result.csv",mode='w')
evaldf
# Out:
# list_len :  172
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1465: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuray = 0.97377  / 0.97377
# precision = 0.57967 / 0.87459
# recall = 0.46355 / 0.69939
# f1_score = 0.49852 / 0.75215
#                             file_name  accuracy  precision    recall  \
# 0                             Average  0.973770   0.579670  0.463550
# 1                    Average(nonzero)  0.973770   0.874590  0.699390
# 0     buildings_AOI_3_Paris_img10.tif  1.000000   0.000000  0.000000
# 1    buildings_AOI_3_Paris_img100.tif  0.967796   0.836972  0.835442
# 2    buildings_AOI_3_Paris_img101.tif  0.964651   0.862640  0.865018
# ..                                ...       ...        ...       ...
# 167   buildings_AOI_3_Paris_img94.tif  1.000000   0.000000  0.000000
# 168   buildings_AOI_3_Paris_img95.tif  1.000000   0.000000  0.000000
# 169   buildings_AOI_3_Paris_img96.tif  0.965839   0.853193  0.753854
# 170   buildings_AOI_3_Paris_img98.tif  1.000000   0.000000  0.000000
# 171   buildings_AOI_3_Paris_img99.tif  0.955191   0.281351  0.902767
#
#      f1_score  bal_accuracy
# 0    0.498520      0.416150
# 1    0.752150      0.627880
# 0    0.000000      0.000000
# 1    0.836206      0.718518
# 2    0.863827      0.760296
# ..        ...           ...
# 167  0.000000      0.000000
# 168  0.000000      0.000000
# 169  0.800453      0.667297
# 170  0.000000      0.000000
# 171  0.429002      0.273076
#
# [174 rows x 6 columns]

# %%
loss_dir = '../result/models_weight/' +aoi + '_' + training_date+'/'
loss_file = loss_dir + 'loss_val_save.csv'
loss = pd.read_csv(loss_file)
loss_arr = loss.values
loss.to_csv(eval_path+"_loss_graph.csv",mode='w')
N=len(loss_arr)
X = np.zeros(N)
X[:] = np.linspace(1,N,N)
Y_max = max(loss_arr)


y_min=min(loss_arr)
# y_min=0.1
# Y_max = 0.5
plt.rcParams['figure.figsize'] = (12,8)
plt.rcParams.update({'font.size': 15})

# title of plot
plt.title('loss' )

# plotting result graph
plt.xlabel('Epoch')  
plt.ylabel('loss') 
plt.xlim(0,N)
plt.ylim(0,Y_max)

plt.tick_params(axis='x', direction='inout', length=10, pad=6, labelsize=14)
plt.tick_params(axis='y', direction='inout', length=10, pad=15, labelsize=12,)

plt.plot(X[:], loss_arr,'-r',label='loss')
plt.grid(True)
plt.legend()
fig1=plt.gcf()
plt.show()
plt.draw()
# if not os.path.exists('result_graph'):
#     os.makedirs('result_graph')   
fig1.savefig(eval_path+'_loss_fig.png',dpi=100)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-99ebc9e300a3> in <module>
#       1 loss_dir = '../result/models_weight/' +aoi + '_' + training_date+'/'
#       2 loss_file = loss_dir + 'loss_val_save.csv'
# ----> 3 loss = pd.read_csv(loss_file)
#       4 loss_arr = loss.values
#       5 loss.to_csv(eval_path+"_loss_graph.csv",mode='w')
#
# ~/anaconda3/envs/solaris2/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     603     kwds.update(kwds_defaults)
#     604
# --> 605     return _read(filepath_or_buffer, kwds)
#     606
#     607
#
# ~/anaconda3/envs/solaris2/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(filepath_or_buffer, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/anaconda3/envs/solaris2/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     812             self.options["has_index_names"] = kwds["has_index_names"]
#     813
# --> 814         self._engine = self._make_engine(self.engine)
#     815
#     816     def close(self):
#
# ~/anaconda3/envs/solaris2/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1043             )
#    1044         # error: Too many arguments for "ParserBase"
# -> 1045         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1046
#    1047     def _failover_to_python(self):
#
# ~/anaconda3/envs/solaris2/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1860
#    1861         # open handles
# -> 1862         self._open_handles(src, kwds)
#    1863         assert self.handles is not None
#    1864         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~/anaconda3/envs/solaris2/lib/python3.7/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1361             compression=kwds.get("compression", None),
#    1362             memory_map=kwds.get("memory_map", False),
# -> 1363             storage_options=kwds.get("storage_options", None),
#    1364         )
#    1365
#
# ~/anaconda3/envs/solaris2/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     642                 encoding=ioargs.encoding,
#     643                 errors=errors,
# --> 644                 newline="",
#     645             )
#     646         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../result/models_weight/AOI_3_Paris_221343/loss_val_save.csv'
