# %% [markdown]
# # Prepare SpaceNet 7 Data for Model Training
#
# We assume that initial steps of README have been executed and that this notebook is running in a docker container.  See the `src` directory for functions used in the algorithm.

# %%
# Dataset location (edit as needed)
root_dir = '../'

# %%
import sys
print(sys.version)
# !python --version
# Out:
# 3.7.8 | packaged by conda-forge | (default, Nov 17 2020, 23:45:15)
# [GCC 7.5.0]
# Python 3.7.8

# %%
from platform import python_version
print(python_version())
# Out:
# 3.7.8

# %%
import multiprocessing
import pandas as pd
import numpy as np
import skimage
import gdal
import sys
import os
sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname("__file__"))))
import matplotlib as mpl
import matplotlib.cm as cmx
import matplotlib.pyplot as plt
import matplotlib.colors as colors
plt.rcParams.update({'font.size': 16})
mpl.rcParams['figure.dpi'] = 300
import vector
# get_list = os.listdir(os.path.join('../data/train/AOI_5_Khartoum_Train/RGB-PanSharpen/'))
# print(len(get_list))
from raster.image import create_multiband_geotiff
from utils.core import _check_gdf_load

# import from data_prep_funcs
module_path = os.path.abspath(os.path.join('../src/'))
if module_path not in sys.path:
    sys.path.append(module_path)
from src.prep_funcs import map_wrapper, make_geojsons_and_masks
# Out:
# /home/hoyin/anaconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/hoyin/anaconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/hoyin/anaconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# Create Training Masks
# Multi-thread to increase speed
# We'll only make a 1-channel mask for now, but Solaris supports a multi-channel mask as well, see
#     https://github.com/CosmiQ/solaris/blob/master/docs/tutorials/notebooks/api_masks_tutorial.ipynb
# mode = 'Train'
mode = 'Test'

aois = sorted([f for f in os.listdir(os.path.join(root_dir, 'data',mode))
               if os.path.isdir(os.path.join(root_dir, 'data',mode, f))])
# print(aois)
# # # aois.remove("AOI_2_Vegas_"+mode)
aois.remove("AOI_3_Paris_Test")
aois.remove("AOI_4_Shanghai_Test")
aois.remove("AOI_5_Khartoum_Test")
n_threads = 10
params = [] 
make_fbc = False

input_args = []
for i, aoi in enumerate(aois):
    print(i, "aoi:", aoi)
    im_dir = os.path.join(root_dir, 'data', mode, aoi, 'RGB/')
#     json_dir = os.path.join(root_dir,'data', 'test', aoi, 'geojson')
    json_dir = os.path.join(root_dir,'data', mode, aoi, 'geojson')
    out_dir_mask = os.path.join(root_dir, 'data', mode, aoi, 'masks/')
#     out_dir_mask_fbc = os.path.join(root_dir, 'data', mode, aoi, 'masks_fbc/')
    os.makedirs(out_dir_mask, exist_ok=True)
    if make_fbc:
        os.makedirs(out_dir_mask_fbc, exist_ok=True)

    json_files = sorted([f
                for f in os.listdir(os.path.join(json_dir))
#                 if f.endswith('Buildings.geojson') and os.path.exists(os.path.join(json_dir, f))])
                if f.endswith('.geojson') and os.path.exists(os.path.join(json_dir, f))])
    for j, f in enumerate(json_files):
        # print(i, j, f)
        name_root = f.split('.')[0]
        json_path = os.path.join(json_dir, f)
#         image_path = os.path.join(im_dir, name_root + '.tif').replace('labels', 'images').replace('_Buildings', '')
        image_path = os.path.join(im_dir, name_root + '.tif').replace('buildings', 'RGB-PanSharpen')
        output_path_mask = os.path.join(out_dir_mask, name_root + '.tif')
        if make_fbc:
            output_path_mask_fbc = os.path.join(out_dir_mask_fbc, name_root + '.tif')
        else:
            output_path_mask_fbc = None
            
        if (os.path.exists(output_path_mask)):
             continue
        else: 
            input_args.append([make_geojsons_and_masks, 
                               name_root, image_path, json_path,
                               output_path_mask, output_path_mask_fbc])

# execute 
print("len input_args", len(input_args))
print("Execute...\n")
with multiprocessing.Pool(n_threads) as pool:
    pool.map(map_wrapper, input_args)
# Out:
# 0 aoi: AOI_2_Vegas_Test
# len input_args 578
# Execute...

# %%
# # Inspect visually

# aoi = 'AOI_2_Vegas_Train'
# im_dir = os.path.join(root_dir, 'data', mode, aoi, 'RGB-PanSharpen')
# mask_dir = os.path.join(root_dir, 'data', mode, aoi, 'masks')

# im_list = sorted([z for z in os.listdir(im_dir) if z.endswith('.tif')])
# im_file = im_list[28]

# im_path = os.path.join(im_dir, im_file)
# mask_path = os.path.join(mask_dir, im_file.split('.')[0] + '.tif').replace('RGB-PanSharpen','buildings')
# im = skimage.io.imread(im_path)
# mask = skimage.io.imread(mask_path)
# print(np.max(mask))
# print(np.min(mask))
# print(type(mask))
# boundary = skimage.segmentation.find_boundaries(mask, mode='subpixel', background=0).astype(np.float32)
# print(type(boundary))
# print(np.max(boundary))
# print(np.min(boundary))
# figsize=(24, 12)
# # name = im_file.split('.')[0].split('global_monthly_')[-1]
# name = im_file.split('.')[0]
# fig, (ax0, ax1) = plt.subplots(1, 2, figsize=figsize)

# _ = ax0.imshow(mask)
# ax0.set_xticks([])
# ax0.set_yticks([])
# _ = ax0.set_title(name)

# _ = ax1.imshow(boundary)
# ax1.set_xticks([])
# ax1.set_yticks([])
# _ = ax1.set_title(name)
# _ = fig.suptitle(name)
# plt.tight_layout()

# %%
# # make identifier plots

# aoi = 'AOI_3_Paris_Test'
# im_dir = os.path.join(root_dir,'data', 'test', aoi, 'RGB-PanSharpen')
# # json_dir = os.path.join(root_dir, 'data','test', aoi, 'geojson', 'buildings')
# json_dir = os.path.join(root_dir, 'data','test', aoi, 'geojson')

# # colors
# vmax = 200
# cmap = plt.get_cmap('hsv')  # 'jet'
# cNorm  = colors.Normalize(vmin=0, vmax=vmax)
# scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=cmap)
# plot_only_first_and_last = True
# label_font_size = 4
# im_pix_size_x, im_pix_size_y = 650, 650
# figsize=(20,20)
# # print(json_dir)
# json_files = sorted([f
#             for f in os.listdir(json_dir) 
#             if f.endswith('.geojson') and os.path.exists(os.path.join(json_dir, f))])
# # print(json_files)
# if plot_only_first_and_last:
#     json_files = [json_files[0], json_files[-1]]
# #     json_files = [json_files[1]]

# # convert json
# for j, f in enumerate(json_files):
#     # print(i, j, f)
#     name_root = f.split('.')[0]
#     json_path = os.path.join(json_dir, f)
#     image_path = os.path.join(im_dir, name_root + '.tif').replace('buildings', 'RGB-PanSharpen')
#     print("name_root:", name_root)
#     # print("json_path", json_path)
#     # output_path = os.path.join(out_dir, f)
#     # if os.path.exists(output_path):
#     #    print("  path exists, skipping:", name_root)
#     #    continue
#     gdf_pix = vector.polygon.geojson_to_px_gdf(json_path, image_path, geom_col='geometry', precision=None, output_path=None, override_crs=False)
#     fig, ax = plt.subplots(figsize=figsize)
#     for _, row in gdf_pix.iterrows():
#         geom = row['geometry']
#         poly_id = row['Id']
#         x, y = geom.exterior.xy
#         cx, cy = np.array(geom.centroid.xy).astype(float)
#         #print("centroid:", centroid)
#         color_int = int(poly_id) % vmax
#         colorVal = scalarMap.to_rgba(color_int)
#         ax.plot(x, y, c=colorVal)
#         # poly id
#         ax.annotate(str(poly_id), xy=(cx, cy), ha='center', size=label_font_size)
#         #text_object = plt.annotate(label, xy=(x_values[i], y_values[i]), ha='center')
#         #ax.text(cx, cy, str(poly_id))
#     ax.set_xlim(0, im_pix_size_x)
#     ax.set_ylim(0, im_pix_size_y)
#     title = str(j) + " - " + name_root + " - N buildings = " + str(len(gdf_pix))
#     ax.set_title(title)

#     plt.show()

# %%
# Make dataframe csvs for train/test
mode = 'Test'
out_dir = os.path.join(root_dir, 'csvs/')
os.makedirs(out_dir, exist_ok=True)

# aois = sorted([f for f in os.listdir(os.path.join(root_dir, 'data',mode))
#                if os.path.isdir(os.path.join(root_dir, 'data',mode, f))])
aoi = 'AOI_2_Vegas_Test'
# aoi = 'AOI_3_Paris_Test'
# aoi = 'AOI_4_Shanghai_Test'
# aoi = 'AOI_5_Khartoum_Test'

d = os.path.join(root_dir, 'data', mode, aoi)
subdirs = sorted([f for f in os.listdir(d)])    
outpath = os.path.join(out_dir, aoi + '_df.csv')
im_list, mask_list = [], []


im_files = [os.path.join( d,'RGB',  f.split('.')[0] + '.tif')
for f in sorted(os.listdir(os.path.join(d,'RGB' ).replace('masks','RGB-PanSharpen')))]

mask_files = [os.path.join(d, 'masks', f.split('.')[0] + '.tif')
for f in sorted(os.listdir(os.path.join(d, 'masks').replace('RGB-PanSharpen','masks')))]


im_list.extend(im_files)
mask_list.extend(mask_files)


df = pd.DataFrame({'image': im_list, 'label': mask_list})
display(df.head())

df.to_csv(outpath, index=False)
print(mode, "len df:", len(df))
print("output csv:", outpath)
# Out:
#                                                image  \
# 0  ../data/Test/AOI_2_Vegas_Test/RGB/RGB-PanSharp...
# 1  ../data/Test/AOI_2_Vegas_Test/RGB/RGB-PanSharp...
# 2  ../data/Test/AOI_2_Vegas_Test/RGB/RGB-PanSharp...
# 3  ../data/Test/AOI_2_Vegas_Test/RGB/RGB-PanSharp...
# 4  ../data/Test/AOI_2_Vegas_Test/RGB/RGB-PanSharp...
#
#                                                label
# 0  ../data/Test/AOI_2_Vegas_Test/masks/buildings_...
# 1  ../data/Test/AOI_2_Vegas_Test/masks/buildings_...
# 2  ../data/Test/AOI_2_Vegas_Test/masks/buildings_...
# 3  ../data/Test/AOI_2_Vegas_Test/masks/buildings_...
# 4  ../data/Test/AOI_2_Vegas_Test/masks/buildings_...
# Test len df: 578
# output csv: ../csvs/AOI_2_Vegas_Test_df.csv

# %% [markdown]
# !Urban3D

# %%
import os 
out_dir = os.path.join(root_dir, 'csvs/')
data_path = '../data/Train/Urban3D_Train/'
rgb_path = os.path.join(data_path + 'RGB')
mask_path = os.path.join(data_path + 'masks')
mask_list = []
mask_files = [os.path.join( mask_path,  f.split('.')[0] + '.tif')
for f in sorted(os.listdir(os.path.join(mask_path)))]
mask_list.extend(mask_files)
# print(mask_list)
# input_list = os.listdir(rgb_path)
# gt_list = os.listdir(mask_path)
# print(gt_list)
# print(mask_list)
# 2708
# 3064

# %%
import skimage
import cv2
mask_list_2 = []
mask_dir = data_path +'masks/'
output_dir = data_path +'masks_cv/'
os.makedirs(output_dir, exist_ok=True)
# for gt in enumerate(mask_list):
# #     print(gt)
#     img = skimage.io.imread(gt[1])
# #     img = cv2.imread(gt[1], cv2.IMREAD_GRAYSCALE)
#     binary = img>2
# #     print(gt[1])
# #     name = gt[1].split('/')[5]
# #     print(name)
#     skimage.io.imsave(os.path.join(output_dir+gt[1].split('/')[5]), binary)
# #     skimage.io.imsave(os.path.join(output_dir+gt[1].split('/')[5]), img)

# %%
mask_list = []
img_list = []
mask_files = [os.path.join( mask_path,  f.split('.')[0] + '.tif')
for f in sorted(os.listdir(os.path.join(mask_path)))]
mask_list.extend(mask_files)
# mask_list
img_files = [os.path.join( rgb_path,  f.split('.')[0] + '.tif')
for f in sorted(os.listdir(os.path.join(rgb_path)))]
img_list.extend(img_files)
print(img_files)
# Out:
# ['../data/Train/Urban3D_Train/RGB/JAX_Tile_013_RGB.tif', '../data/Train/Urban3D_Train/RGB/JAX_Tile_014_RGB.tif', '../data/Train/Urban3D_Train/RGB/JAX_Tile_015_RGB.tif', '../data/Train/Urban3D_Train/RGB/JAX_Tile_016_RGB.tif', '../data/Train/Urban3D_Train/RGB/JAX_Tile_017_RGB.tif', '../data/Train/Urban3D_Train/RGB/JAX_Tile_018_RGB.tif', '../data/Train/Urban3D_Train/RGB/JAX_Tile_019_RGB.tif', '../data/Train/Urban3D_Train/RGB/JAX_Tile_020_RGB.tif', '../data/Train/Urban3D_Train/RGB/JAX_Tile_022_RGB.tif', '../data/Train/Urban3D_Train/RGB/JAX_Tile_023_RGB.tif', '../data/Train/Urban3D_Train/RGB/JAX_Tile_025_RGB.tif', '../data/Train/Urban3D_Train/RGB/JAX_Tile_026_RGB.tif', '../data/Train/Urban3D_Train/RGB/JAX_Tile_027_RGB.tif', '../data/Train/Urban3D_Train/RGB/JAX_Tile_028_RGB.tif', '../data/Train/Urban3D_Train/RGB/JAX_Tile_029_RGB.tif', '../data/Train/Urban3D_Train/RGB/JAX_Tile_030_RGB.tif', '../data/Train/Urban3D_Train/RGB/JAX_Tile_031_RGB.tif', '../data/Train/Urban3D_Train/RGB/JAX_Tile_032
# ...

# %%
img_list
# Out:
# ['../data/Train/Urban3D_Train/RGB/JAX_Tile_013_RGB.tif',
#  '../data/Train/Urban3D_Train/RGB/JAX_Tile_014_RGB.tif',
#  '../data/Train/Urban3D_Train/RGB/JAX_Tile_015_RGB.tif',
#  '../data/Train/Urban3D_Train/RGB/JAX_Tile_016_RGB.tif',
#  '../data/Train/Urban3D_Train/RGB/JAX_Tile_017_RGB.tif',
#  '../data/Train/Urban3D_Train/RGB/JAX_Tile_018_RGB.tif',
#  '../data/Train/Urban3D_Train/RGB/JAX_Tile_019_RGB.tif',
#  '../data/Train/Urban3D_Train/RGB/JAX_Tile_020_RGB.tif',
#  '../data/Train/Urban3D_Train/RGB/JAX_Tile_022_RGB.tif',
#  '../data/Train/Urban3D_Train/RGB/JAX_Tile_023_RGB.tif',
#  '../data/Train/Urban3D_Train/RGB/JAX_Tile_025_RGB.tif',
#  '../data/Train/Urban3D_Train/RGB/JAX_Tile_026_RGB.tif',
#  '../data/Train/Urban3D_Train/RGB/JAX_Tile_027_RGB.tif',
#  '../data/Train/Urban3D_Train/RGB/JAX_Tile_028_RGB.tif',
#  '../data/Train/Urban3D_Train/RGB/JAX_Tile_029_RGB.tif',
#  '../data/Train/Urban3D_Train/RGB/JAX_Tile_030_RGB.tif',
# ...

# %%
from skimage import data
import matplotlib.pyplot as plt
split_dir = data_path  + 'rgb_split/'
# split_dir = data_path  + 'mask_split/'
os.makedirs(split_dir, exist_ok=True)
quad_list = []
# for img in enumerate(mask_list) :
for img in enumerate(img_list) :
#     print(img[1])
    mask = skimage.io.imread(img[1])
#     print(mask.shape)
    height, width,channel = mask.shape
    hsplit, csplit = height//4, width//4
    m11,m12,m13,m14,m21,m22,m23,m24,m31,m32,m33,m34,m41,m42,m43,m44=mask[:hsplit, :csplit], mask[hsplit:2*hsplit, :csplit], mask[2*hsplit:3*hsplit, :csplit], mask[3*hsplit:4*hsplit, :csplit], mask[:hsplit, csplit:2*csplit], mask[hsplit:2*hsplit, csplit:2*csplit], mask[2*hsplit:3*hsplit, csplit:2*csplit], mask[3*hsplit:4*hsplit, csplit:2*csplit], mask[:hsplit, 2*csplit:3*csplit], mask[hsplit:2*hsplit,  2*csplit:3*csplit], mask[2*hsplit:3*hsplit,  2*csplit:3*csplit], mask[3*hsplit:4*hsplit,  2*csplit:3*csplit], mask[:hsplit, 3*csplit:4*csplit], mask[hsplit:2*hsplit, 3*csplit:4*csplit], mask[2*hsplit:3*hsplit, 3*csplit:4*csplit], mask[3*hsplit:4*hsplit, 3*csplit:4*csplit] 

#     quadrants  = [
#         mask[:hsplit, :csplit], mask[hsplit:2*hsplit, :csplit], mask[2*hsplit:3*hsplit, :csplit], mask[3*hsplit:4*hsplit, :csplit], 
#         mask[:hsplit, csplit:2*csplit], mask[hsplit:2*hsplit, csplit:2*csplit], mask[2*hsplit:3*hsplit, csplit:2*csplit], mask[3*hsplit:4*hsplit, csplit:2*csplit], 
#         mask[:hsplit, 2*csplit:3*csplit], mask[hsplit:2*hsplit,  2*csplit:3*csplit], mask[2*hsplit:3*hsplit,  2*csplit:3*csplit], mask[3*hsplit:4*hsplit,  2*csplit:3*csplit], 
#         mask[:hsplit, 3*csplit:4*csplit], mask[hsplit:2*hsplit, 3*csplit:4*csplit], mask[2*hsplit:3*hsplit, 3*csplit:4*csplit], mask[3*hsplit:4*hsplit, 3*csplit:4*csplit] 
# ] 
#     quad_list.append(quadrants)
    skimage.io.imsave(os.path.join(split_dir+'_1_'+img[1].split('/')[5]), m11)
    skimage.io.imsave(os.path.join(split_dir+'_2_'+img[1].split('/')[5]), m12)
    skimage.io.imsave(os.path.join(split_dir+'_3_'+img[1].split('/')[5]), m13)
    skimage.io.imsave(os.path.join(split_dir+'_4_'+img[1].split('/')[5]), m14)
    skimage.io.imsave(os.path.join(split_dir+'_5_'+img[1].split('/')[5]), m21)
    skimage.io.imsave(os.path.join(split_dir+'_6_'+img[1].split('/')[5]), m22)
    skimage.io.imsave(os.path.join(split_dir+'_7_'+img[1].split('/')[5]), m23)
    skimage.io.imsave(os.path.join(split_dir+'_8_'+img[1].split('/')[5]), m24)
    skimage.io.imsave(os.path.join(split_dir+'_9_'+img[1].split('/')[5]), m31)
    skimage.io.imsave(os.path.join(split_dir+'_10_'+img[1].split('/')[5]), m32)
    skimage.io.imsave(os.path.join(split_dir+'_11_'+img[1].split('/')[5]), m33)
    skimage.io.imsave(os.path.join(split_dir+'_12_'+img[1].split('/')[5]), m34)
    skimage.io.imsave(os.path.join(split_dir+'_13_'+img[1].split('/')[5]), m41)
    skimage.io.imsave(os.path.join(split_dir+'_14_'+img[1].split('/')[5]), m42)
    skimage.io.imsave(os.path.join(split_dir+'_15_'+img[1].split('/')[5]), m43)
    skimage.io.imsave(os.path.join(split_dir+'_16_'+img[1].split('/')[5]), m44)
    
#     print(img)

# fig, axes = plt.subplots(4, 4)
# print(quad_list[1])
# for quad_list[1], ax in zip(quadrants, axes.flat):
#     ax.imshow(quadrant, cmap='gray')
#     ax.set_axis_off()
# Out:
# /home/hoyin/anaconda3/envs/solaris/lib/python3.7/site-packages/ipykernel_launcher.py:35: UserWarning: ../data/Train/Urban3D_Train/rgb_split/_13_JAX_Tile_044_RGB.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris/lib/python3.7/site-packages/ipykernel_launcher.py:33: UserWarning: ../data/Train/Urban3D_Train/rgb_split/_11_JAX_Tile_052_RGB.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris/lib/python3.7/site-packages/ipykernel_launcher.py:36: UserWarning: ../data/Train/Urban3D_Train/rgb_split/_14_JAX_Tile_052_RGB.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris/lib/python3.7/site-packages/ipykernel_launcher.py:37: UserWarning: ../data/Train/Urban3D_Train/rgb_split/_15_JAX_Tile_052_RGB.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: ../data/Train/Urban3D_Train/rgb_split/_5_JAX_Tile_053_RGB.tif is a low contrast image
# ...

# %% [markdown]
# WHU

# %%
import skimage
import cv2
mask_list_2 = []
mask_dir = data_path +'masks/'
output_dir = data_path +'masks_cv/'
os.makedirs(output_dir, exist_ok=True)
for gt in enumerate(mask_list):
#     print(gt)
#     img = skimage.io.imread(gt[1])
    img = cv2.imread(gt[1], cv2.IMREAD_GRAYSCALE)
#     binary = img>2
#     print(gt[1])
#     name = gt[1].split('/')[5]
#     print(name)
#     skimage.io.imsave(os.path.join(output_dir+gt[1].split('/')[5]), binary)
    skimage.io.imsave(os.path.join(output_dir+gt[1].split('/')[5]), img)



from PIL import Image
import PIL.Image as pilimg
im_list = sorted([z for z in os.listdir(os.path.join(data_path,'RGB')) if z.endswith('.tif')])
# sample_name= im_list[25]
sample_name= im_list[27]
# sample_name= im_list[30]
# print(sample_name)
gt_path = os.path.join(data_path, 'masks', sample_name)
image_pt = os.path.join(data_path, 'RGB', sample_name)

print(gt_path)
gt_image = cv2.imread(gt_path)
# gt_image = skimage.io.imread(gt_path)
# gt_image=pilimg.open(gt_path)
imag = skimage.io.imread(image_pt)




# print("gt.shape:", gt_image.shape)
# print("min, max", np.min(gt_image), np.max(gt_image))
print("infer_image.shape:", imag.shape)
print("min, max", np.min(imag), np.max(imag))



fig = plt.figure(figsize=(8,8))
rows=2
cols=1
ax0 = fig.add_subplot(rows, cols, 1)
ax1 = fig.add_subplot(rows, cols, 2)
ax0.imshow(gt_image,cmap='gray')
ax0.axis('off')
ax0.set_title('Image')
ax1.imshow(imag)
ax1.axis('off')
ax1.set_title('Infer Image')
plt.suptitle(sample_name.split('.')[0])
plt.tight_layout()
plt.show()
# Out:
# ../data/Test/WHU/masks/122.tif
# infer_image.shape: (512, 512, 3)
# min, max 0 255

# %%
print(type(gt_image))

temp_var = np.array(gt_image)
print(type(gt_image))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
os.path.join('sample.tif', gt_image)

# %%
skimage.io.imsave('sample.tif', gt_image)
a=skimage.io.imread('sample.tif')
print(np.min(a))
print(np.max(a))
fig = plt.figure(figsize=(8,8))
rows=1
cols=1
ax0 = fig.add_subplot(rows, cols, 1)

ax0.imshow(a,cmap='gray')
ax0.axis('off')
ax0.set_title('Image')
# ax1.imshow(imag)
# ax1.axis('off')
# ax1.set_title('Infer Image')
plt.suptitle(sample_name.split('.')[0])
plt.tight_layout()
plt.show()
# Out:
# 0
# 255

# %%
# Make dataframe csvs for train/test
mode = 'Train'
root_dir = '../'
out_dir = os.path.join(root_dir, 'csvs/')
os.makedirs(out_dir, exist_ok=True)

# aois = sorted([f for f in os.listdir(os.path.join(root_dir, 'data',mode))
#                if os.path.isdir(os.path.join(root_dir, 'data',mode, f))])
aoi = 'Urban3D_Train'
# aoi = 'WHU_Train'
# aoi = 'AOI_3_Paris_Test'
# aoi = 'AOI_4_Shanghai_Test'
# aoi = 'AOI_5_Khartoum_Test'

d = os.path.join(root_dir, 'data', mode, aoi)
subdirs = sorted([f for f in os.listdir(d)])    
outpath = os.path.join(out_dir, aoi +'_df.csv')
im_list, mask_list = [], []


im_files = [os.path.join( d,'RGB',  f.split('.')[0] + '.tif')
for f in sorted(os.listdir(os.path.join(d,'RGB' ).replace('masks','RGB-PanSharpen')))]

mask_files = [os.path.join(d, 'masks', f.split('.')[0] + '.tif')
for f in sorted(os.listdir(os.path.join(d, 'masks').replace('RGB-PanSharpen','masks')))]


im_list.extend(im_files)
mask_list.extend(mask_files)


df = pd.DataFrame({'image': im_list, 'label': mask_list})
display(df.head())

df.to_csv(outpath, index=False)
print(mode, "len df:", len(df))
print("output csv:", outpath)
# Out:
#                                                image  \
# 0  ../data/Test/Urban3D_Test/RGB/RIC_Tile_000_RGB...
# 1  ../data/Test/Urban3D_Test/RGB/RIC_Tile_001_RGB...
# 2  ../data/Test/Urban3D_Test/RGB/RIC_Tile_002_RGB...
# 3  ../data/Test/Urban3D_Test/RGB/RIC_Tile_013_RGB...
# 4  ../data/Test/Urban3D_Test/RGB/RIC_Tile_014_RGB...
#
#                                                label
# 0  ../data/Test/Urban3D_Test/masks/RIC_Tile_000_G...
# 1  ../data/Test/Urban3D_Test/masks/RIC_Tile_001_G...
# 2  ../data/Test/Urban3D_Test/masks/RIC_Tile_002_G...
# 3  ../data/Test/Urban3D_Test/masks/RIC_Tile_013_G...
# 4  ../data/Test/Urban3D_Test/masks/RIC_Tile_014_G...
# Test len df: 42
# output csv: ../csvs/Urban3D_Test_df.csv
