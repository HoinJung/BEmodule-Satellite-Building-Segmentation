# %%
import matplotlib.pyplot as plt
import numpy as np
import skimage.io
import sklearn.metrics as sm
import sys
import os
import datetime
from skimage import img_as_uint
from skimage.filters import threshold_otsu, threshold_niblack
import cv2
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib
import pandas as pd
import shutil


plt.rcParams.update({'font.size': 6})
mpl.rcParams['figure.dpi'] = 300
sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname("__file__"))))
os.environ['CUDA_VISIBLE_DEVICES']='2'
aois = 7
training_date = '32937'
# aois = 3
# training_date = '117213'
dirmode= False
# dirmode= True
if aois ==2 :
    aoi = 'AOI_2_Vegas'
elif aois == 3: 
    aoi = 'AOI_3_Paris'
elif aois == 4: 
    aoi = 'AOI_4_Shanghai'
elif aois==5 :
    aoi = 'AOI_5_Khartoum'
elif aois==6 :
    aoi = 'Urban3D'
elif aois==7 :
    aoi = 'WHU'

im_dir = '../data/Test/' + aoi + '_Test/'
pred_top_dir = '../result/'

# %%
def revision_metric(sq_segment_mask_ori, sq_segment_mask_pred):
    #sq_segment_mask_ori_ = list(sq_segment_mask_ori.ravel().astype(int))
    #sq_segment_mask_pred_ = list(sq_segment_mask_pred.ravel().astype(int))
    sq_segment_mask_ori_ = sq_segment_mask_ori.ravel().astype(int)
    sq_segment_mask_pred_ = sq_segment_mask_pred.ravel().astype(int)
    
    accuracy_ = sm.accuracy_score(sq_segment_mask_ori_, sq_segment_mask_pred_)
    bal_accu = sm.jaccard_score(sq_segment_mask_ori_, sq_segment_mask_pred_)
    f1_score = sm.f1_score(sq_segment_mask_ori_, sq_segment_mask_pred_)
    recall = sm.recall_score(sq_segment_mask_ori_, sq_segment_mask_pred_)
    precision = sm.precision_score(sq_segment_mask_ori_, sq_segment_mask_pred_)
    
    return accuracy_,  f1_score, recall, precision, bal_accu
#     tn, fp, fn, tp =  sm.confusion_matrix(sq_segment_mask_ori_, sq_segment_mask_pred_).ravel()
#     FAR = float(fp)/(tn+fp)*100
    
#     return accuracy_, f1_score, recall, precision, FAR

# %%
#get mask
if dirmode:
    infer_dir = os.path.join(pred_top_dir+ 'infer'+ '/'+ aoi + '_' + training_date+'/check_mask_presigmoid/')
else :
    infer_dir = os.path.join(pred_top_dir+ 'infer'+ '/'+ aoi + '_' + training_date)
out_dir_mask = os.path.join(pred_top_dir+ 'infer_masks'+ '/' +aoi  +'_' + training_date)
print(infer_dir)
print(out_dir_mask)
if os.path.isdir(out_dir_mask) :
    shutil.rmtree(out_dir_mask)
    os.makedirs(out_dir_mask, exist_ok=True)
else : 
    os.makedirs(out_dir_mask, exist_ok=True)
im_list = sorted([z for z in os.listdir(infer_dir) if z.endswith('.tif')])


for i,j in enumerate(im_list):
    name_root = j.split('.')[0]
#     print(name_root)
    image_path = os.path.join(infer_dir,name_root+'.tif')
    if dirmode:
        mask_path = os.path.join(out_dir_mask,name_root+'.tif').replace('sum_infer_AOI','pred_mask_AOI')
    else : 
        mask_path = os.path.join(out_dir_mask,name_root+'.tif').replace('mask_AOI','pred_mask_AOI')
    mask_image = skimage.io.imread(image_path)
    
    binary = mask_image > 0

    skimage.io.imsave(mask_path, binary)
# Out:
# ../result/infer/WHU_32937
# ../result/infer_masks/WHU_32937
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/0.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/0.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/1.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/10.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/10.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/100.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/101.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/101.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/102.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/103.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/103.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/104.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/105.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/106.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/107.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/108.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/109.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/109.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/11.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/11.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/110.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/111.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/112.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/113.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/114.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/115.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/115.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/116.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/116.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/117.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/117.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/118.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/119.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/119.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/12.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/12.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/120.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/121.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/122.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/122.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/123.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/124.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/125.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/126.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/126.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/127.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/128.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/129.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/13.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/13.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/130.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/130.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/131.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/131.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/132.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/132.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/133.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/134.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/134.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/135.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/135.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/136.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/137.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/138.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/139.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/14.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/14.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/140.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/141.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/142.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/143.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/144.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/145.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/145.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/146.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/147.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/148.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/149.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/15.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/15.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/150.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/150.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/151.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/152.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/153.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/153.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/154.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/155.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/156.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/157.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/158.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/159.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/16.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/16.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/160.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/161.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/161.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/162.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/162.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/163.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/163.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/164.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/164.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/165.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/166.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/167.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/168.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/168.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/169.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/169.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/17.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/17.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/170.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/170.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/171.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/172.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/173.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/173.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/174.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/174.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/175.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/175.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/176.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/177.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/178.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/179.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/179.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/18.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/180.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/181.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/181.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/182.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/183.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/184.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/184.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/185.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/186.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/186.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/187.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/187.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/188.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/189.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/19.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/190.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/190.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/191.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/191.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/192.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/193.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/194.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/195.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/195.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/196.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/197.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/198.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/199.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/199.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/2.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/20.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/20.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/200.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/201.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/202.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/202.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/203.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/204.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/205.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/206.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/207.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/208.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/208.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/209.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/21.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/210.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/210.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/211.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/211.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/212.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/212.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/213.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/214.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/215.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/216.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/217.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/218.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/219.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/22.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/220.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/220.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/221.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/222.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/222.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/223.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/224.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/224.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/225.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/226.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/227.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/227.tif is a low contrast image
# ...
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/7.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/70.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/700.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/700.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/701.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/701.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/702.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/702.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/703.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/703.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/704.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/704.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/705.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/706.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/707.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/708.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/709.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/71.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/71.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/710.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/711.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/712.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/713.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/72.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/72.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/73.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/73.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/74.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/74.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/75.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/76.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/77.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/77.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/78.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/79.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/79.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/8.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/8.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/80.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/81.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/82.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/82.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/83.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/84.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/85.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/85.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/86.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/87.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/88.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/88.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/89.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/9.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/9.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/90.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/91.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/91.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/92.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/92.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/93.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/94.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/95.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/96.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/96.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/97.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/98.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/98.tif is a low contrast image
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: ../result/infer_masks/WHU_32937/99.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.

# %%
import re
import random

# additional functions
def atoi(text):
    return int(text) if text.isdigit() else text
    
def natural_keys(text):
    return [ atoi(c) for c in re.split('(\d+)', text) ]

# %%
#compare target, ground truth, prediction
import skimage
import skimage.segmentation
import copy
if aois == 6:
    im_list = sorted([z for z in os.listdir(os.path.join(im_dir,'RGB')) if z.endswith('.tif')])
    sample_name= im_list[30]

    gt_path = os.path.join(im_dir, 'masks', sample_name).replace('RGB','GTL')
    image_pt = os.path.join(im_dir, 'RGB', sample_name)
    infer_path = os.path.join(infer_dir+ '/'+ sample_name).replace('RGB-PanSharpen','mask')
    prediction_path = os.path.join(out_dir_mask+ '/'+ sample_name).replace('RGB-PanSharpen','pred_mask')
else : 
    im_list = sorted([z for z in os.listdir(os.path.join(im_dir,'RGB')) if z.endswith('.tif')])
#     print(im_list)
    im_list.sort(key=natural_keys)
    sample_name= im_list[121]

    gt_path = os.path.join(im_dir, 'masks', sample_name).replace('RGB-PanSharpen','buildings')
    image_pt = os.path.join(im_dir, 'RGB', sample_name)
    if dirmode:
        infer_path = os.path.join(infer_dir+ '/'+ sample_name).replace('RGB-PanSharpen','sum_infer')
    else : 
        infer_path = os.path.join(infer_dir+ '/'+ sample_name).replace('RGB-PanSharpen','mask')
    prediction_path = os.path.join(out_dir_mask+ '/'+ sample_name).replace('RGB-PanSharpen','pred_mask')


img = cv2.imread(image_pt,cv2.IMREAD_UNCHANGED )
img = img.astype(np.uint16)
# cv2.imwrite('processed.tif',img )

gt_image = skimage.io.imread(gt_path)
infer_image = skimage.io.imread(infer_path)
mask_image = skimage.io.imread(prediction_path)
binary = mask_image > 0
# temp_infer = copy.copy(infer_image)
# temp_infer[ temp_infer >=0 ] = 255
# temp_infer[ temp_infer < 0 ] = 0

boundary = skimage.segmentation.find_boundaries(binary, mode='inner', background=0).astype(np.float32)
boundary=boundary*255
print("mask_image.shape:", mask_image.shape)
print("min, max", np.min(mask_image), np.max(mask_image))
print("gt.shape:", gt_image.shape)
print("min, max", np.min(gt_image), np.max(gt_image))
print("infer_image.shape:", infer_image.shape)
print("min, max", np.min(infer_image), np.max(infer_image))
print("boundary:", boundary.shape)
print("min, max", np.min(boundary), np.max(boundary))
#1 boundary ground truth를 255를 곱하자
#2 boundary output에도 255 곱하고.. 그래야 balance가 맞을듯.

print(np.unique(boundary))
fig = plt.figure(figsize=(4,4))
rows=2
cols=2
ax0 = fig.add_subplot(rows, cols, 1)
ax1 = fig.add_subplot(rows, cols, 2)
ax2 = fig.add_subplot(rows, cols, 3)
ax3 = fig.add_subplot(rows, cols, 4)
ax0.imshow(img)
# ax0.imshow(infer_image,cmap='gray')
ax0.axis('off')
ax0.set_title('Image')
ax1.imshow(gt_image,cmap='gray')
ax1.axis('off')
ax1.set_title('Ground Truth')
ax2.imshow(infer_image,cmap='gray')
ax2.axis('off')
ax2.set_title('Infer Image')
ax3.imshow(mask_image,cmap='gray')
#ax3.axis('off')
ax3.set_title('Prediction Mask')
plt.suptitle(sample_name.split('.')[0])
plt.tight_layout()
plt.show()
# Out:
# mask_image.shape: (512, 512)
# min, max 0 255
# gt.shape: (512, 512)
# min, max 0 255
# infer_image.shape: (512, 512)
# min, max -30.99554 5.8762546
# boundary: (512, 512)
# min, max 0.0 255.0
# [  0. 255.]

# %%
# from sklearn.metrics import roc_curve
# from sklearn.metrics import roc_auc_score

# testy = gt_image/255.
# ns_probs = mask_image

# s_auc = roc_auc_score(testy, ns_probs)
 
# # summarize scores
# #print('No Skill: ROC AUC=%.3f' % (ns_auc))
 
# # calculate roc curves
# ns_fpr, ns_tpr, _ = roc_curve(testy, ns_probs)
 
# # plot the roc curve for the model
# plt.plot(ns_fpr, ns_tpr, linestyle='--', label='No Skill')
 
# # show the plot
# plt.show()

# %%
# im_list = sorted([z for z in os.listdir(os.path.join(im_dir,'RGB')) if z.endswith('.tif')])
# sample_name= im_list[25]
# sample_name= im_list[20]
# sample_name= im_list[30]
# print(sample_name)
gt_path = os.path.join(im_dir, 'masks', sample_name).replace('RGB-PanSharpen','buildings')
# gt_path = os.path.join(im_dir, 'masks', sample_name).replace('RGB','GTL')
image_pt = os.path.join(im_dir, 'RGB', sample_name)
if dirmode:
    infer_path = os.path.join(infer_dir+ '/'+ sample_name).replace('RGB-PanSharpen','sum_infer')
else : 
    infer_path = os.path.join(infer_dir+ '/'+ 'check_mask_presigmoid/'+sample_name).replace('RGB-PanSharpen','sum_infer')
#     infer_path = os.path.join(infer_dir+ '/'+ sample_name).replace('RGB-PanSharpen','mask')
# prediction_path = os.path.join(out_dir_mask+ '/'+ sample_name).replace('RGB-PanSharpen','pred_mask')
boundary_path = os.path.join(infer_dir+ '/'+ 'boundary/'+sample_name).replace('RGB-PanSharpen','Boundary')
sum_path = os.path.join(infer_dir+ '/'+ 'binary/'+sample_name).replace('RGB-PanSharpen','binary')
gt_image2 = skimage.io.imread(gt_path)
infer_image2 = skimage.io.imread(infer_path)
boundary_image = skimage.io.imread(boundary_path)
sum_image = skimage.io.imread(sum_path)

# a=200
# b=a+40
# c=50

##후보1
# a=300
# b=a+100
# c=200
# N=100

a=380
b=a+25
c=230
N=25

X = np.zeros(N)
X[:] = np.linspace(1,N,N)
Y_max = 1.3
y_min=0.0
print(mask_image.shape)
infer_arr = infer_image2[a:b,c]
gt_arr = gt_image2[a:b,c]/255
boundary_arr = boundary_image[a:b,c]
boundary_arr2 = boundary_image[a:b,c]
test_arr =np.clip(4.2*boundary_arr2 + infer_arr,0,1)
sum_arr = sum_image[a:b,c]
plt.rcParams['figure.figsize'] = (10,6)
plt.rcParams.update({'font.size': 7})
# title of plot
plt.title('Combining Probability Map' )
# plotting result graph
plt.xlabel('x')  
plt.ylabel('P(x)') 
plt.xlim(0,N)
plt.ylim(y_min,Y_max)
plt.yticks(np.arange(y_min, Y_max,step=0.5))
# plt.tick_params(axis='x', direction='inout', length=6, pad=6, labelsize=6)
# plt.tick_params(axis='y', direction='inout', length=6, pad=15, labelsize=6,)
plt.plot(X[:], infer_arr,'-r',label='Mask Prediction')
plt.plot(X[:], boundary_arr2,'-b',label='Boundary Prediction')
plt.plot(X[:], gt_arr,'-k',label='Ground Truth')
# plt.plot(X[:], boundary_arr,'-b',label='boundary')
# plt.plot(X[:], sum_arr,'-k',label='sum(mask+edge)')

plt.plot(X[:], test_arr,'-.k',label='Boundary Enhanced Mask')
# plt.grid(True)
plt.legend()

ax = plt.gca()
ax.axes.xaxis.set_visible(False)
fig1=plt.gcf()

plt.axis()
plt.show()
plt.draw()
fig2=plt.gcf()
fig2.savefig(eval_path+'_loss_fig67.png',dpi=100,bbox_inches='tight')

if not os.path.exists('result_graph'):
    os.makedirs('result_graph')   
fig1.savefig(eval_path+'_loss_fig77.png',dpi=100,bbox_inches='tight')
# Out:
# (512, 512)

# %%
eval_result = revision_metric(gt_image/255., mask_image/255.)
print(eval_result)
# Out:
# (0.9822273254394531, 0.9619806924916151, 0.9763296947209753, 0.9480473525059512, 0.9267464348044842)

# %%
def average(list):
    return (sum(list) / len(list))

eval_path = os.path.join(pred_top_dir+'eval_result'+'/'+aoi+'_'+training_date)
os.makedirs(eval_path, exist_ok=True)
gt_list= sorted([z for z in os.listdir(os.path.join(im_dir,'masks').replace('GTL','RGB')) if z.endswith('.tif')])
# mask_list=sorted([z for z in os.listdir(os.path.join(pred_top_dir,'infer_masks')) if z.endswith('.tif')])
print("list_len : ", len(gt_list))
print(gt_list[0])
eval_list = []
mask_list=[]
acc_list=[]
f1_list = []
rec_list = []
prec_list = []
bal_acc_list=[]
for i,j in enumerate(gt_list) : 
    mask_name = j.split('.')[0]
#     print(mask_name)
    gt_array = skimage.io.imread(os.path.join(im_dir, 'masks',mask_name+'.tif'))
#     eval_mask = os.path.join(out_dir_mask+ '/'+mask_name+'.tif').replace('GTL','RGB')
    eval_mask = os.path.join(out_dir_mask+ '/'+mask_name+'.tif').replace('buildings','pred_mask')
    
#     eval_mask = os.path.join(pred_top_dir, 'infer_masks',mask_name+'.tif').replace('buildings','pred_mask')
    mask_array = skimage.io.imread(eval_mask)
    eval_result = revision_metric(gt_array/255., mask_array/255.)
    
#     print("accuracy : %.3f " % eval_result[0], end=',')
#     print("f1_score : %.3f " % eval_result[1], end=',')
#     print("recall : %.3f " % eval_result[2], end=',')
#     print("precision : %.3f " % eval_result[3])
    
    acc_list.append(eval_result[0])
    f1_list.append(eval_result[1])
    rec_list.append(eval_result[2])
    prec_list.append(eval_result[3])
    bal_acc_list.append(eval_result[4])



acc_list_nonzero = [i for i in acc_list if i > 0 ] 
f1_list_nonzero = [i for i in f1_list if i > 0 ]    
rec_list_nonzero = [i for i in rec_list if i > 0 ]    
prec_list_nonzero = [i for i in prec_list if i > 0 ]  
bal_acc_list_nonzero = [i for i in bal_acc_list if i > 0 ]  


a=round(average(acc_list),5)
b=round(average(f1_list),5)
c=round(average(rec_list),5)
d=round(average(prec_list),5)
e=round(average(acc_list_nonzero),5)
f=round(average(f1_list_nonzero),5)
g=round(average(rec_list_nonzero),5)
h=round(average(prec_list_nonzero),5)

x=round(average(bal_acc_list),5)
y= round(average(bal_acc_list_nonzero),5)


print("accuray = %.5f  / %.5f" % (a,e))
print("precision = %.5f / %.5f" % (d, h))
print("recall = %.5f / %.5f" % (c, g))
print("f1_score = %.5f / %.5f" % (b, f))



eval_df = pd.DataFrame(columns=['file_name','accuracy',  'precision', 'recall', 'f1_score','bal_accuracy'])
eval_df.loc[0] = ("Average",a,d,c,b,x)
eval_df.loc[1] = ("Average(nonzero)",e,h,g,f,y)
eval_result = pd.DataFrame([x for x in zip(gt_list,acc_list, prec_list, rec_list, f1_list,bal_acc_list )], columns=['file_name','accuracy',  'precision', 'recall', 'f1_score', 'bal_accuracy'])    
evaldf = eval_df.append(eval_result)

evaldf.to_csv(eval_path+"_eval_result.csv",mode='w')
evaldf
# Out:
# list_len :  2416
# 0.tif
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1465: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /home/hoyin/anaconda3/envs/solaris2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuray = 0.98556  / 0.98556
# precision = 0.64422 / 0.91825
# recall = 0.64859 / 0.92448
# f1_score = 0.64234 / 0.91558
#              file_name  accuracy  precision    recall  f1_score  bal_accuracy
# 0              Average  0.985560   0.644220  0.648590  0.642340      0.600450
# 1     Average(nonzero)  0.985560   0.918250  0.924480  0.915580      0.855860
# 0                0.tif  0.999981   0.000000  0.000000  0.000000      0.000000
# 1                1.tif  0.998596   0.960148  0.971311  0.965697      0.933670
# 2               10.tif  0.996162   0.493750  0.883130  0.633382      0.463467
# ...                ...       ...        ...       ...       ...           ...
# 2411            95.tif  0.979332   0.951841  0.906211  0.928466      0.866483
# 2412            96.tif  1.000000   0.000000  0.000000  0.000000      0.000000
# 2413            97.tif  0.999134   0.962313  0.983527  0.972805      0.947049
# 2414            98.tif  0.998985   0.972185  0.915593  0.943041      0.892220
# 2415            99.tif  0.996403   0.910842  0.949498  0.929768      0.868754
#
# [2418 rows x 6 columns]

# %%
loss_dir = '../result/models_weight/' +aoi + '_' + training_date+'/'
loss_file = loss_dir + 'loss_val_save.csv'
loss = pd.read_csv(loss_file)
loss_arr = loss.values
loss.to_csv(eval_path+"_loss_graph.csv",mode='w')
N=len(loss_arr)
X = np.zeros(N)
X[:] = np.linspace(1,N,N)
Y_max = max(loss_arr)


y_min=min(loss_arr)
# y_min=0.1
# Y_max = 0.5
plt.rcParams['figure.figsize'] = (12,8)
plt.rcParams.update({'font.size': 15})

# title of plot
plt.title('loss' )

# plotting result graph
plt.xlabel('Epoch')  
plt.ylabel('loss') 
plt.xlim(0,N)
plt.ylim(0,Y_max)

plt.tick_params(axis='x', direction='inout', length=10, pad=6, labelsize=14)
plt.tick_params(axis='y', direction='inout', length=10, pad=15, labelsize=12,)

plt.plot(X[:], loss_arr,'-r',label='loss')
plt.grid(True)
plt.legend()
fig1=plt.gcf()
plt.show()
plt.draw()
# if not os.path.exists('result_graph'):
#     os.makedirs('result_graph')   
fig1.savefig(eval_path+'_loss_fig.png',dpi=100)

# %%
# id_list = ['292053','1311818','129949','251549','2191020','2201539'] #상하이
id_list = ['1141937','125830','128234','232358','2191020','2211227']
# aoi = 'AOI_4_Shanghai_'
aoi = 'AOI_5_Khartoum_'
pic_num = '540'
# pic_num = '182'
result_img_list = []
for id_ in id_list :
    result_img = os.path.join('../result/infer_masks/'+aoi+id_+'/'+'pred_mask_'+aoi+'img'+pic_num+'.tif')
    result_img_list.append(result_img)
# print(result_img_list)
unet = skimage.io.imread(result_img_list[0])
unet_be= skimage.io.imread(result_img_list[1])
resunet= skimage.io.imread(result_img_list[2])
resunet_be= skimage.io.imread(result_img_list[3])
ternaus= skimage.io.imread(result_img_list[4])
ternaus_be= skimage.io.imread(result_img_list[5])

origin_path = '../data/Test/'+aoi+'Test/'
gt_imgae = skimage.io.imread(os.path.join(origin_path+'masks/buildings_'+aoi+'img'+pic_num+'.tif'))
rgb_imgae = skimage.io.imread(os.path.join(origin_path+'RGB/RGB-PanSharpen_'+aoi+'img'+pic_num+'.tif'))
# rgb_imgae = cv2.imread((os.path.join(origin_path+'RGB/RGB-PanSharpen_'+aoi+'img'+pic_num+'.tif',cv2.IMREAD_UNCHANGED )))
# rgb_imgae = rgb_imgae.astype(np.uint16)
# fig = plt.figure(figsize=(4,4))
fig = plt.figure(figsize=(8,16))
rows=4
cols=2
ax0 = fig.add_subplot(rows, cols, 1)
ax1 = fig.add_subplot(rows, cols, 2)
ax2 = fig.add_subplot(rows, cols, 3)
ax3 = fig.add_subplot(rows, cols, 4)
ax4 = fig.add_subplot(rows, cols, 5)
ax5 = fig.add_subplot(rows, cols, 6)
ax6 = fig.add_subplot(rows, cols, 7)
ax7 = fig.add_subplot(rows, cols, 8)


ax0.imshow(unet,cmap='gray')
ax0.axis('off')
ax0.set_title('unet')

ax1.imshow(unet_be,cmap='gray')
ax1.axis('off')
ax1.set_title('unet_be')

ax2.imshow(resunet,cmap='gray')
ax2.axis('off')
ax2.set_title('resunet')

ax3.imshow(resunet_be,cmap='gray')
ax3.axis('off')
ax3.set_title('resunet_be')

ax4.imshow(ternaus,cmap='gray')
ax4.axis('off')
ax4.set_title('ternaus')

ax5.imshow(ternaus_be,cmap='gray')
ax5.axis('off')
ax5.set_title('ternaus_be')

ax6.imshow(rgb_imgae,cmap='gray')
ax6.axis('off')
ax6.set_title('rgb_imgae')

ax7.imshow(gt_imgae,cmap='gray')
ax7.axis('off')
ax7.set_title('gt_imgae')
plt.suptitle(pic_num)
plt.tight_layout()
plt.show()

# %%
import shutil

shutil.copy(os.path.join(origin_path+'RGB/RGB-PanSharpen_'+aoi+'img'+pic_num+'.tif'), '../result/ppt/'+aoi+'rgb'+'.png')
count=0
for id_ in id_list:
#     result_img_list
    skimage.io.imsave('../result/ppt/'+aoi+id_+'.png', skimage.io.imread(result_img_list[count]))
    count += 1
skimage.io.imsave('../result/ppt/'+aoi+'gt'+'.png',gt_imgae)
# skimage.io.imsave('../result/ppt/'+aoi+'rgb'+'.png', rgb_imgae)
# skimage.io.imsave('../result/ppt/'+aoi+'gt'+'.png', os.path.join(origin_path+'masks/buildings_'+aoi+'img'+pic_num+'.tif'))
# skimage.io.imsave('../result/ppt/'+aoi+'rgb'+'.png', os.path.join(origin_path+'RGB/RGB-PanSharpen_'+aoi+'img'+pic_num+'.tif'))

# gt_imgae = skimage.io.imread(os.path.join(origin_path+'masks/buildings_'+aoi+'img'+pic_num+'.tif'))
# rgb_imgae

# %%
# import tifffile as tiff
# a = tiff.imread(os.path.join(origin_path+'RGB/RGB-PanSharpen_'+aoi+'img'+pic_num+'.tif'))
# # tiff.imsave('../result/ppt/'+aoi+'rgb22'+'.png', a)
# a2 = a.astype(np.uint8)
# skimage.io.imsave('../result/ppt/'+aoi+'rgb'+'.png', a2)
# Out:
# <class 'int'>
# <class 'str'>
