# %%
import matplotlib.pyplot as plt
import numpy as np
import skimage.io
import sklearn.metrics as sm
import sys
import os
import datetime
from skimage import img_as_uint
from skimage.filters import threshold_otsu, threshold_niblack
import cv2
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib
import pandas as pd
import shutil


plt.rcParams.update({'font.size': 6})
mpl.rcParams['figure.dpi'] = 300
sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname("__file__"))))
aois = 6
training_date = '1629034179'
if aois ==2 :
    aoi = 'AOI_2_Vegas'
elif aois == 3: 
    aoi = 'AOI_3_Paris'
elif aois == 4: 
    aoi = 'AOI_4_Shanghai'
elif aois==5 :
    aoi = 'AOI_5_Khartoum'
elif aois==6 :
    aoi = 'Urban3D'
elif aois==7 :
    aoi = 'WHU'

im_dir = '../data/Test/' + aoi + '_Test/'
pred_top_dir = '../result/'

# %%
def revision_metric(gt, pred):
    gt = gt.ravel().astype(int)
    pred = pred.ravel().astype(int)
    accuracy_ = sm.accuracy_score(gt, pred)
    bal_accu = sm.jaccard_score(gt, pred)
    f1_score = sm.f1_score(gt, pred)
    recall = sm.recall_score(gt, pred)
    precision = sm.precision_score(gt, pred)
    
    return accuracy_, f1_score, recall, precision, bal_accu

# %%
#get mask from infered image

infer_dir = os.path.join(pred_top_dir+ 'infer'+ '/'+ aoi + '_' + training_date)
out_dir_mask = os.path.join(pred_top_dir+ 'infer_masks'+ '/' +aoi  +'_' + training_date)
print(infer_dir)
print(out_dir_mask)
if os.path.isdir(out_dir_mask) :
    shutil.rmtree(out_dir_mask)
    os.makedirs(out_dir_mask, exist_ok=True)
else : 
    os.makedirs(out_dir_mask, exist_ok=True)
im_list = sorted([z for z in os.listdir(infer_dir) if z.endswith('.tif')])
for i,j in enumerate(im_list):
    name_root = j.split('.')[0]
    image_path = os.path.join(infer_dir,name_root+'.tif')
    mask_path = os.path.join(out_dir_mask,name_root+'.tif')
    mask_image = skimage.io.imread(image_path)
    
    binary = mask_image > 0

    skimage.io.imsave(mask_path, binary)
# Out:
# ../result/infer/Urban3D_1629034179
# ../result/infer_masks/Urban3D_1629034179
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_000_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_001_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_002_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_013_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_014_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_015_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_027_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_028_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_029_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_030_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_032_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_033_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_040_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_041_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_042_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_043_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_044_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_055_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_056_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_059_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_065_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_071_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_087_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_089_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_091_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_092_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_097_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_098_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_099_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_100_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_101_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_111_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_113_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_121_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_122_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_123_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_124_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_125_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_128_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_129_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_133_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_134_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_000_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_001_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_002_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_013_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_014_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_015_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_027_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_028_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_029_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_030_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_032_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_033_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_040_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_041_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_042_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_042_RGB.tif is a low contrast image
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_043_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_044_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_055_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_056_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_059_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_065_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_071_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_087_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_089_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_091_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_092_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_097_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_098_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_099_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_100_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_101_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_111_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_113_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_121_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_122_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_123_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_124_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_125_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_128_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_129_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_133_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_11_RIC_Tile_134_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_000_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_001_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_002_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_013_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_014_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_015_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_027_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_028_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_029_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_030_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_032_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_033_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_040_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_041_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_042_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_043_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_044_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_055_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_056_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_059_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_065_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_071_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_087_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_089_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_091_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_092_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_097_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_098_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_099_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_099_RGB.tif is a low contrast image
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_100_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_101_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_111_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_113_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_121_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_122_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_123_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_124_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_125_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_128_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_129_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_133_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_133_RGB.tif is a low contrast image
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_134_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_12_RIC_Tile_134_RGB.tif is a low contrast image
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_000_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_001_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_001_RGB.tif is a low contrast image
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_002_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_013_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_014_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_015_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_027_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_028_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_029_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_030_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_032_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_033_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_040_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_041_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_042_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_043_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_044_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_055_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_056_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_059_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_059_RGB.tif is a low contrast image
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_065_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_071_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_071_RGB.tif is a low contrast image
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_087_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_089_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_091_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_091_RGB.tif is a low contrast image
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_092_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_097_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_098_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_099_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_100_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_101_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_111_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_111_RGB.tif is a low contrast image
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_113_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_121_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_122_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_123_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_124_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_125_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_128_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_129_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_133_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_13_RIC_Tile_134_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_14_RIC_Tile_000_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_14_RIC_Tile_001_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_14_RIC_Tile_002_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# ...
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_8_RIC_Tile_099_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_8_RIC_Tile_100_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_8_RIC_Tile_101_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_8_RIC_Tile_111_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_8_RIC_Tile_113_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_8_RIC_Tile_121_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_8_RIC_Tile_122_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_8_RIC_Tile_123_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_8_RIC_Tile_124_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_8_RIC_Tile_125_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_8_RIC_Tile_128_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_8_RIC_Tile_129_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_8_RIC_Tile_133_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_8_RIC_Tile_133_RGB.tif is a low contrast image
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_8_RIC_Tile_134_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_8_RIC_Tile_134_RGB.tif is a low contrast image
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_000_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_001_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_002_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_013_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_014_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_015_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_027_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_028_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_029_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_030_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_032_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_033_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_040_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_041_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_042_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_043_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_044_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_055_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_056_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_059_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_059_RGB.tif is a low contrast image
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_065_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_071_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_087_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_089_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_091_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_092_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_097_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_098_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_099_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_100_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_101_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_111_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_111_RGB.tif is a low contrast image
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_113_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_121_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_122_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_123_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_124_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_125_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_128_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_129_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_133_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: ../result/infer_masks/Urban3D_1629034179/_9_RIC_Tile_134_RGB.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.

# %%
#compare target, ground truth, prediction
import skimage
import skimage.segmentation
import copy

im_list = sorted([z for z in os.listdir(os.path.join(im_dir,'RGB')) if z.endswith('.tif')])
sample_name= im_list[25]

gt_path = os.path.join(im_dir, 'masks', sample_name).replace('RGB','GTL')
image_pt = os.path.join(im_dir, 'RGB', sample_name)
infer_path = os.path.join(infer_dir+ '/'+ sample_name)
prediction_path = os.path.join(out_dir_mask+ '/'+ sample_name)

print(infer_path)
print(prediction_path)
img = cv2.imread(image_pt,cv2.IMREAD_UNCHANGED )
img = img.astype(np.uint16)
gt_image = skimage.io.imread(gt_path)
infer_image = skimage.io.imread(infer_path)
infer_image = np.squeeze(infer_image.transpose(2,3,1,0),axis=2)
mask_image = skimage.io.imread(prediction_path)
mask_image = np.squeeze(mask_image.transpose(2,3,1,0),axis=2)
boundary = skimage.segmentation.find_boundaries(binary, mode='inner', background=0).astype(np.float32)
boundary=boundary*255

fig = plt.figure(figsize=(4,4))
rows=2
cols=2
ax0 = fig.add_subplot(rows, cols, 1)
ax1 = fig.add_subplot(rows, cols, 2)
ax2 = fig.add_subplot(rows, cols, 3)
ax3 = fig.add_subplot(rows, cols, 4)
ax0.imshow(img)
# ax0.imshow(infer_image,cmap='gray')
ax0.axis('off')
ax0.set_title('Image')
ax1.imshow(gt_image,cmap='gray')
ax1.axis('off')
ax1.set_title('Ground Truth')
ax2.imshow(infer_image,cmap='gray')
ax2.axis('off')
ax2.set_title('Infer Image')
ax3.imshow(mask_image,cmap='gray')
ax3.axis('off')
ax3.set_title('Prediction Mask')
plt.suptitle(sample_name.split('.')[0])
plt.tight_layout()
plt.show()
# Out:
# ../result/infer/Urban3D_1629034179/_10_RIC_Tile_092_RGB.tif
# ../result/infer_masks/Urban3D_1629034179/_10_RIC_Tile_092_RGB.tif

# %%
def average(list):
    return (sum(list) / len(list))

eval_path = os.path.join(pred_top_dir+'eval_result'+'/'+aoi+'_'+training_date)
os.makedirs(eval_path, exist_ok=True)
gt_list= sorted([z for z in os.listdir(os.path.join(im_dir,'masks')) if z.endswith('.tif')])
print("list_len : ", len(gt_list))
eval_list = []
mask_list=[]
acc_list=[]
f1_list = []
rec_list = []
prec_list = []
bal_acc_list=[]
for i,j in enumerate(gt_list) : 
    mask_name = j.split('.')[0]

    gt_array = skimage.io.imread(os.path.join(im_dir, 'masks',mask_name+'.tif'))
    eval_mask = os.path.join(out_dir_mask+ '/'+mask_name+'.tif').replace('GTL','RGB')
    mask_array = skimage.io.imread(eval_mask)
    eval_result = revision_metric(gt_array/255., mask_array/255.)
    acc_list.append(eval_result[0])
    f1_list.append(eval_result[1])
    rec_list.append(eval_result[2])
    prec_list.append(eval_result[3])
    bal_acc_list.append(eval_result[4])
acc_list_nonzero = [i for i in acc_list if i > 0 ] 
f1_list_nonzero = [i for i in f1_list if i > 0 ]    
rec_list_nonzero = [i for i in rec_list if i > 0 ]    
prec_list_nonzero = [i for i in prec_list if i > 0 ]  
bal_acc_list_nonzero = [i for i in bal_acc_list if i > 0 ]  
a=round(average(acc_list_nonzero),5)
b=round(average(prec_list_nonzero),5)
c=round(average(rec_list_nonzero),5)
d=round(average(f1_list_nonzero),5)
e= round(average(bal_acc_list_nonzero),5)

print("accuray = %.5f" % a)
print("precision = %.5f" % b)
print("recall = %.5f" % c)
print("f1_score = %.5f" % d)

eval_df = pd.DataFrame(columns=['file_name','accuracy',  'precision', 'recall', 'f1_score','bal_accuracy'])
eval_df.loc[0] = ("Average",a,b,c,d,e)
eval_result = pd.DataFrame([x for x in zip(gt_list,acc_list, prec_list, rec_list, f1_list,bal_acc_list )], columns=['file_name','accuracy',  'precision', 'recall', 'f1_score', 'bal_accuracy'])    
evaldf = eval_df.append(eval_result)

evaldf.to_csv(eval_path+"_eval_result.csv",mode='w')
evaldf
# Out:
# list_len :  672
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1496: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1496: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1496: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1496: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1496: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1496: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1496: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1496: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1496: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1496: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1496: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1496: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1496: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1496: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1496: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1496: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuray = 0.89347  / 0.89347
# precision = 0.49826 / 0.52399
# recall = 0.85696 / 0.90121
# f1_score = 0.60949 / 0.64096
#                     file_name  accuracy  precision    recall  f1_score  \
# 0                     Average  0.893470   0.498260  0.856960  0.609490
# 1            Average(nonzero)  0.893470   0.523990  0.901210  0.640960
# 0    _10_RIC_Tile_000_GTL.tif  0.844749   0.700693  0.804491  0.749013
# 1    _10_RIC_Tile_001_GTL.tif  0.899551   0.683620  0.904401  0.778663
# 2    _10_RIC_Tile_002_GTL.tif  0.912025   0.174884  0.893031  0.292490
# ..                        ...       ...        ...       ...       ...
# 667   _9_RIC_Tile_125_GTL.tif  0.836700   0.173372  0.959254  0.293667
# 668   _9_RIC_Tile_128_GTL.tif  0.902023   0.333898  0.961902  0.495720
# 669   _9_RIC_Tile_129_GTL.tif  0.951122   0.403023  0.842382  0.545203
# 670   _9_RIC_Tile_133_GTL.tif  0.909027   0.411117  0.942513  0.572509
# 671   _9_RIC_Tile_134_GTL.tif  0.967831   0.310985  0.845396  0.454704
#
#      bal_accuracy
# 0        0.461760
# 1        0.485600
# 0        0.598738
# 1        0.637550
# 2        0.171296
# ..            ...
# 667      0.172104
# 668      0.329540
# 669      0.374762
# 670      0.401060
# 671      0.294251
#
# [674 rows x 6 columns]
